# %% [markdown]
# # Palmer Penguin Case Study
#
# ## About Data
# The Palmer Penguins dataset is a well-known dataset available in SQL Public Datasets, consisting of measurements of different penguin species that were collected from three islands( ie. Biscoe, Dream, Torgersen) in the Palmer Archipelago, Antarctica.
#
# Dataset was collected by Dr. Kristen Gorman and the Palmer Station Long Term Ecological Research (LTER) team. It contains 344 observations of penguin species, including Adélie, Chinstrap, and Gentoo, along with 7 variables such as species, island, culmen length, culmen depth, flipper length, body mass and sex.
#
# ## Objective
# 1. Is there any relationship between bill length, body mass and penguin species?
# 2. Looking for trends in species and sex of penguins.
# 3. Record of species percentage in islands.
#
# ## Process
# 1. I have used SQL for organising and cleaning the data. [Link for SQL](http://console.cloud.google.com/bigquery?sq=554595511095:7df80afeefe9423bbcfa58ecb4344809)
# 2. Used Amazon Quicksight for Data Visualization. [Link for Tableau Dashboard](https://public.tableau.com/app/profile/sharvari.tribhuwan/viz/Palmer_penguins_dashboard/Dashboard1)

# %% [markdown]
# ## Analysis
# 1.  [Link for Scatterplot](https://public.tableau.com/app/profile/sharvari.tribhuwan/viz/Palmer_penguins_dashboard/Dashboard1): The scatter plot displays the relationship between body mass and flipper length of different species of penguins. The plot reveals a positive correlation between body mass and flipper length, which is but obvious as larger the bodymass, bigger the flipper length will be. Scatterplot also shows that Adelie and Chinstrap penguins have a similar distribution, while Gentoo penguins have a relatively larger body mass and longer flipper length.
#
# 2. [Link for Bargraph](https://public.tableau.com/app/profile/sharvari.tribhuwan/viz/Palmer_penguins_dashboard/Dashboard1): While finding trends or patterns between sex of different species, by analyzing we dont see much difference between male and female population. Both male and female of species have same density of population.
#
# 3. [Link for Species piechart](https://public.tableau.com/app/profile/sharvari.tribhuwan/viz/Palmer_penguins_dashboard/Dashboard1): Record of species percentage by island:-
#  * Biscoe island has a record of 74%  Gentoo species and 26%  Adelie species penguin whereas Chinstrap
#    species penguins are not present on Biscoe island.
#  * Dream island consists of 55% Chinstrap species and 45% Adelie species penguins.
#  * Whereas Torgersen island only consists of Adelie penguin species.
