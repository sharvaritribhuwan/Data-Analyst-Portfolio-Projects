# %% [markdown]
# # Youtube Video Data Analysis

# %% [markdown]
# ## Business Task:-
# Comprehensive analysis of Shagun Agarwal YouTube Channel and rating the videos based on the content to help in finding the most popular content and thus thriving in growth of the channel.
#
#
# ## Questions
# 1. Select video data from the Shagun Agarwal YouTube Channel and provide a comprehensive analysis of it in your own words.
# 2. Rate the top 5 videos in terms of content.
#
# ## Stakeholders
# * Shagun Agarwal : Popular Youtube Channel content creater.

# %% [markdown]
# # Prepare
#
# **Storing and organising Data:-**
#
# I've filtered and sorted the Data in Spreadsheets in csv format.
#
#
# **Biasness or credibility:-**
#
# No biasness found in this data.
#
# **Licensing, Privacy, Security, and Accessibility of Data**
#
# * Licensing-CC0: Public Domain
#
# * Accessibility of Data - Dataset used in this case study is a Public Data source so it has free acess, usage, and sharing of data.

# %% [markdown]
# # Analyze and Share
#
# * I have used Tableau for Data analysis and visualization
#
# 1. I've attached a link to a dashboard I created in tableau for more understanding of analysis, it's based on the average comments, average likes and average views.
# 2. [Click here to see the Tableau Dashboard which explains the analysis.](https://public.tableau.com/app/profile/sharvari.tribhuwan/viz/Youtube_video_analysis/Dashboard1)
# 2. Though some videos have higher rate of likes, the comments and views do not reach the average range which is required for the content of video to be popular.
# 3. Hence, I have selected 5 top video contents where likes, comments and views all reach or come in the average range.

# %% [markdown]
# # Conclusion
# * Based on the analysis of the video contents which are based on average range of likes and comments and views.
#
# * These are my 5 top rated videos based on the content:-
#
# 1. Master these 10 habits for guaranteed success in 2023.
# 2. How I landed a job in USA.
# 3. How to use your body language to change your life.
# 4. How to find your career sweet spot.
# 5. How does social comparison affects us.
